# %%
from alpr.alpr import ALPR
import cv2
import yaml
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob

with open('config.yaml', 'r') as stream:
    cfg = yaml.safe_load(stream)

# %%
SOURCE_DIR =glob.glob('../../../FOTOS/*.jpg')
SOURCE_DIR =glob.glob('../../../FOTOS/truck*.*')
# SOURCE_DIR =glob.glob('../cnn-ocr-lp/benchmark/imgs/*.png')
print(SOURCE_DIR)
cv2_images = []
plt_images = []
name_images = []
images = [cv2.imread(file) for file in SOURCE_DIR]
for file in SOURCE_DIR:
    name_images.append(file)
    cv2_images.append(cv2.imread(file))
    plt_images.append(mpimg.imread(file))

# Check how to use it
# is_img = cv2.haveImageReader(video_path)
# Out:
# ['../../../FOTOS/truck7.jpeg', '../../../FOTOS/truck6.jpeg', '../../../FOTOS/truck1.jpeg', '../../../FOTOS/truck3.jpeg', '../../../FOTOS/truck2.jpeg', '../../../FOTOS/truck10.jpeg', '../../../FOTOS/truck9.jpeg', '../../../FOTOS/truck5.jpeg', '../../../FOTOS/truck4.jpeg', '../../../FOTOS/truck8.jpeg']

# %%
SOURCE_DIR
# Out:
# []

# %%
fig = plt.figure(figsize=(20, 10))
for i, x in enumerate(plt_images):
#   image, label = next(train_iter)
  fig.add_subplot(1, len(plt_images), i+1)
  plt.imshow(x)
  plt.axis('off')
  plt.title(name_images[i]);

# %%
alpr = ALPR(cfg['modelo'], cfg['db'])

for i, x in enumerate(cv2_images):
    frame = cv2_images[i]
    # frame_w_pred = alpr.mostrar_predicts(frame)
    # cv2.namedWindow("result", cv2.WINDOW_AUTOSIZE)
    # cv2.imshow("result", frame_w_pred)
    # cv2.waitKey()


    predicciones = alpr.predict(frame)
    print(f"{name_images[i]}: {predicciones}")


# for i, x in enumerate(cv2_images):
#     predicciones = alpr.predict(cv2_images[i])
#     print(f"{name_images[i]}: {predicciones}")
# Out:
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# ../../../FOTOS/truck7.jpeg: ['AE750VW']
# ../../../FOTOS/truck6.jpeg: []
# ../../../FOTOS/truck1.jpeg: []
# ../../../FOTOS/truck3.jpeg: []
# ../../../FOTOS/truck2.jpeg: []
# ../../../FOTOS/truck10.jpeg: ['AB015SB']
# ../../../FOTOS/truck9.jpeg: ['AE329ZD']
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# ../../../FOTOS/truck5.jpeg: ['HIF279']
# ../../../FOTOS/truck4.jpeg: []
# ../../../FOTOS/truck8.jpeg: ['KHH817']
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"
# warning: loc("mps_resize"("(mpsFileLoc): /AppleInternal/Library/BuildRoots/91a344b1-f985-11ee-b563-fe8bc7981bff/Library/Caches/com.apple.xbs/Sources/MetalPerformanceShadersGraph/mpsgraph/MetalPerformanceShadersGraph/Core/Files/MPSGraphUtilities.mm":180:0)): 'anec.resize' op Invalid configuration for the following reasons: Error: Invalid tensor format: "fp32"

# %%
# cap = cv2.VideoCapture('../videoplayback1.mp4')
# cap = cv2.VideoCapture('./assets/test_patente.mp4')

# while True:
    # return_value, frame = cap.read()
    # if return_value:
    #     frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
